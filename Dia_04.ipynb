# %% [markdown]
# <a href="https://colab.research.google.com/github/Edu-Fidelis/ProjetoDataScience/blob/main/Dia_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('sds_fifa_atualizado.csv')

# %%
dados.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ... Salario  Total_Pontos
# 0           0             0  ...   95000          2064
# 1           1             1  ...    2000          1439
# 2           2             2  ...   46000          2075
# 3           3             3  ...   50000          2008
# 4           4             4  ...  270000          2276
#
# [5 rows x 10 columns]

# %%
dados.drop('Unnamed: 0', axis=1, inplace=True)

# %%
dados.head()
# Out:
#    Unnamed: 0.1               Nome  ...  Salario Total_Pontos
# 0             0         J. Lingard  ...    95000         2064
# 1             1   A. Bella-Kotchap  ...     2000         1439
# 2             2          T. Souček  ...    46000         2075
# 3             3    Felipe Anderson  ...    50000         2008
# 4             4       A. Griezmann  ...   270000         2276
#
# [5 rows x 9 columns]

# %%
dados.plot()

# %%
dados.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4463d56d68>,
# ...
#       dtype=object)

# %%
dados.corr()
# Out:
#               Unnamed: 0.1     Idade  ...   Salario  Total_Pontos
# Unnamed: 0.1      1.000000 -0.000441  ...  0.002012      0.003962
# Idade            -0.000441  1.000000  ...  0.608475      0.314829
# Media            -0.001340  0.507420  ...  0.778381      0.810494
# Potencial         0.001878 -0.347528  ...  0.359933      0.470998
# Salario           0.002012  0.608475  ...  1.000000      0.625144
# Total_Pontos      0.003962  0.314829  ...  0.625144      1.000000
#
# [6 rows x 6 columns]

# %%
dados.columns
# Out:
# Index(['Unnamed: 0.1', 'Nome', 'Idade', 'Posicao', 'Media', 'Potencial',
#        'Time', 'Salario', 'Total_Pontos'],
#       dtype='object')

# %%
dados.drop('Unnamed: 0.1', axis=1, inplace=True)

# %%
dados.columns
# Out:
# Index(['Nome', 'Idade', 'Posicao', 'Media', 'Potencial', 'Time', 'Salario',
#        'Total_Pontos'],
#       dtype='object')

# %%
dados.plot()

# %%
colunas = ['Nome', 'Idade', 'Posicao', 'Media', 'Potencial', 'Time', 'Salario',
       'Total_Pontos']

# %%
plt.figure(figsize=(20, 12))

# %%
sns.heatmap(dados[colunas].corr(), annot=True)

# %%
sns.clustermap(dados[colunas].corr(), annot=False)

# %%
plt.figure(figsize=(10,5))
pl = sns.boxplot(x=dados['Time'][1:12], y=dados['Media'], palette='hls');
pl.set_title(label='Média por Clube');
plt.xlabel('Time')
plt.ylabel('Média')
plt.yticks(rotation=80)
plt.ylim(85, 95)
# Out:
# (85.0, 95.0)

# %%
sns.jointplot(dados['Idade'], dados['Media'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(dados['Media'], dados['Salario'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot('Idade', 'Media', data = dados)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot('Idade', 'Media', data = dados, kind='box').fig.set_size_inches(11, 7)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
